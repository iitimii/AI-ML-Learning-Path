# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('max_columns', 200)

# %%
data = pd.read_csv('C:/Users/Timii/Documents/Dev/Zummit/AI-ML-Learning-Path/house_prices_data/train.csv')

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 436    437          50       RM         40.0     4400   Pave   NaN      Reg
# 653    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 71      72          20       RL         69.0     7599   Pave   NaN      Reg
# 1266  1267         190       RM         60.0    10120   Pave   NaN      IR1
# 431    432          50       RM         60.0     5586   Pave   NaN      IR1
# 180    181         160       FV          NaN     2117   Pave   NaN      Reg
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
# 139    140          60       RL         65.0    15426   Pave   NaN      IR1
# 746    747          60       RL          NaN     8795   Pave   NaN      IR1
# 1317  1318         120       FV         47.0     4230   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
few_cols = ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

for i in few_cols:
    print(data[i].value_counts())
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
data.query('Fireplaces != 0')[['FireplaceQu']].isna().sum()
# Out:
# FireplaceQu    0
# dtype: int64

# %%
# fire_dict = {'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5, np.nan:0}
# data['FireplaceQu'] = data['FireplaceQu'].map(fire_dict)
data['FireplaceQu'] = data['FireplaceQu'].fillna('None')

# %%
data['Alley'] = data['Alley'].fillna('None')

# %%
data.query('PoolArea != 0')[['PoolArea', 'PoolQC']]
# Out:
#       PoolArea PoolQC
# 197        512     Ex
# 810        648     Fa
# 1170       576     Gd
# 1182       555     Ex
# 1298       480     Gd
# 1386       519     Fa
# 1423       738     Gd

# %%
data['PoolQC'] = data['PoolQC'].fillna('None')

# %%
data['Fence'] = data['Fence'].fillna('None')

# %%
data.query('MiscVal != 0')['MiscFeature'].isna().sum()
# Out:
# 0

# %%
data['MiscFeature'] = data['MiscFeature'].fillna('None')

# %%
data[data['MasVnrType'].isna()][['MasVnrArea', 'MasVnrType']]
# Out:
#       MasVnrArea MasVnrType
# 234          NaN        NaN
# 529          NaN        NaN
# 650          NaN        NaN
# 936          NaN        NaN
# 973          NaN        NaN
# 977          NaN        NaN
# 1243         NaN        NaN
# 1278         NaN        NaN

# %%
data.query('~MasVnrArea.isna()')['MasVnrType'].isna().sum()
# Out:
# 0

# %%
data['MasVnrArea'] = data['MasVnrArea'].fillna(0)
data['MasVnrType'] = data['MasVnrType'].fillna('None')

# %%
data.drop('LotFrontage', axis=1, inplace=True)

# %%
data['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
data.drop(columns=['BsmtExposure'])
base_col = ['BsmtQual','BsmtCond', 'BsmtFinType1',
       'BsmtFinType2']
data[base_col]
# Out:
#      BsmtQual BsmtCond BsmtFinType1 BsmtFinType2
# 0          Gd       TA          GLQ          Unf
# 1          Gd       TA          ALQ          Unf
# 2          Gd       TA          GLQ          Unf
# 3          TA       Gd          ALQ          Unf
# 4          Gd       TA          GLQ          Unf
# ...       ...      ...          ...          ...
# 1455       Gd       TA          Unf          Unf
# 1456       Gd       TA          ALQ          Rec
# 1457       TA       Gd          GLQ          Unf
# 1458       TA       TA          GLQ          Rec
# 1459       TA       TA          BLQ          LwQ
#
# [1460 rows x 4 columns]

# %%
data.query('BsmtFinType2.isna()')[base_col]
# Out:
#      BsmtQual BsmtCond BsmtFinType1 BsmtFinType2
# 17        NaN      NaN          NaN          NaN
# 39        NaN      NaN          NaN          NaN
# 90        NaN      NaN          NaN          NaN
# 102       NaN      NaN          NaN          NaN
# 156       NaN      NaN          NaN          NaN
# 182       NaN      NaN          NaN          NaN
# 259       NaN      NaN          NaN          NaN
# 332        Gd       TA          GLQ          NaN
# 342       NaN      NaN          NaN          NaN
# 362       NaN      NaN          NaN          NaN
# 371       NaN      NaN          NaN          NaN
# 392       NaN      NaN          NaN          NaN
# 520       NaN      NaN          NaN          NaN
# 532       NaN      NaN          NaN          NaN
# 533       NaN      NaN          NaN          NaN
# 553       NaN      NaN          NaN          NaN
# 646       NaN      NaN          NaN          NaN
# 705       NaN      NaN          NaN          NaN
# ...

# %%
for i in base_col:
    print(data[i].value_counts())
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
data[base_col] = data[base_col].fillna('None')
data.drop('BsmtExposure',axis=1, inplace=True)

# %%
data.Electrical.value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
data.query('Electrical.isna()')
# Out:
#         Id  MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 1379  1380          80       RL     9735   Pave  None      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# 1379    AllPub    Inside       Gtl       Timber       Norm       Norm
#
#      BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1379     1Fam       SLvl            5            5       2006          2007
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 1379     Gable  CompShg     VinylSd     VinylSd       None         0.0
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtFinType1  \
# 1379        TA        TA      PConc       Gd       TA          Unf
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 1379           0          Unf           0        384          384    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# ...

# %%
data['Electrical'] = data['Electrical'].fillna(data['Electrical'].value_counts().index[0])

# %%
gar_col = ['GarageType','GarageYrBlt', 'GarageFinish',
           'GarageQual','GarageCond']

data[gar_col]
# Out:
#      GarageType  GarageYrBlt GarageFinish GarageQual GarageCond
# 0        Attchd       2003.0          RFn         TA         TA
# 1        Attchd       1976.0          RFn         TA         TA
# 2        Attchd       2001.0          RFn         TA         TA
# 3        Detchd       1998.0          Unf         TA         TA
# 4        Attchd       2000.0          RFn         TA         TA
# ...         ...          ...          ...        ...        ...
# 1455     Attchd       1999.0          RFn         TA         TA
# 1456     Attchd       1978.0          Unf         TA         TA
# 1457     Attchd       1941.0          RFn         TA         TA
# 1458     Attchd       1950.0          Unf         TA         TA
# 1459     Attchd       1965.0          Fin         TA         TA
#
# [1460 rows x 5 columns]

# %%
data.GarageType.value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
data[gar_col].isna().sum()
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
data[gar_col] = data[gar_col].fillna('None')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
data = data.drop('Id', axis=1)
data
# Out:
#       MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0             60       RL     8450   Pave  None      Reg         Lvl
# 1             20       RL     9600   Pave  None      Reg         Lvl
# 2             60       RL    11250   Pave  None      IR1         Lvl
# 3             70       RL     9550   Pave  None      IR1         Lvl
# 4             60       RL    14260   Pave  None      IR1         Lvl
# ...          ...      ...      ...    ...   ...      ...         ...
# 1455          60       RL     7917   Pave  None      Reg         Lvl
# 1456          20       RL    13175   Pave  None      Reg         Lvl
# 1457          70       RL     9042   Pave  None      Reg         Lvl
# 1458          20       RL     9717   Pave  None      Reg         Lvl
# 1459          20       RL     9937   Pave  None      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# ...

# %%
cat_hot = ['Street', 'Alley', 'LandContour', '	LotConfig', 'Neighborhood', 'Condition1']

cat_ord = ['MSSubClass', 'MSZoning', 'LotShape', 'Utilities', 'LandSlope']

num_col = ['LotArea', '']

# %%
cols = data.corr()['SalePrice'].sort_values(ascending=False)
cols
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# ...

# %%
cols = cols[:11].index
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd'],
#       dtype='object')

# %%
df = data[cols]

# %%
sns.pairplot(df, diag_kind='kde')

# %%
y = df['SalePrice']
X = df.drop(columns=["GarageCars", "SalePrice"], axis=1)

# %%
X.sample(7)
# Out:
#       OverallQual  GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF  FullBath  \
# 359             8       1924         592         1086      1086         2
# 1367            5       1475         336          757       925         2
# 1364            7       1200         480          600       520         2
# 837             6        987         264          483       483         1
# 566             9       2504         656         1122      1134         2
# 766             7       1714         496          980       980         2
# 810             6       1309         484         1040      1309         1
#
#       TotRmsAbvGrd  YearBuilt  YearRemodAdd
# 359              7       1998          1998
# 1367             6       1977          1977
# 1364             4       2005          2005
# 837              5       1973          1973
# 566             11       2005          2007
# 766              7       1988          1988
# 810              5       1974          1999

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PolynomialFeatures

# %%
model = LinearRegression()

pipeline = Pipeline([('scale', StandardScaler()),
                      # ('transform', QuantileTransformer(n_quantiles=100)),
                      ('poly', PolynomialFeatures(degree=2)),
                      ('model', model)])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('poly', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)
plt.scatter(y_pred, y_test);

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 20642.91029425988
